# %% [markdown]
# # Process PubMed data and export  to TSVs

# %%
import bz2
import datetime
import importlib
import itertools
import logging
import mimetypes
import os
import re
import xml.etree.ElementTree

import pandas

# %% [markdown]
# # Extract historical dates from PubMed records

# %%
encoding_to_module = {
    'gzip': 'gzip',
    'bzip2': 'bz2',
}

def iterparse(path):
    """First yield the ElementTree root, then yield elements from an XML file."""
    # Automatically detect compression
    type_, encoding = mimetypes.guess_type(path)
    if encoding is None:
        opener = open
    else:
        module = encoding_to_module[encoding]
        opener = importlib.import_module(module).open
    # Open file and yield from the element tree
    with opener(path, 'rt') as read_file:
        context = xml.etree.ElementTree.iterparse(read_file, events=('start', 'end'))
        yield next(context)[1]
        yield from (elem for event, elem in context if event == 'end')

# %%
def parse_date_text(text):
    """
    Parse an `eSummaryResult/DocSum/Item[@Name='History']/Item[@Type='Date']` element.
    The time on the date is discarded. A `datetime.date` object is returned
    """
    date_, time_ = text.split(' ')
    date_tuple = date_.split('/')
    year, month, day = map(int, date_tuple)
    return datetime.date(year, month, day)

# %%
def parse_esummary_history(docsum):
    """docsum is an xml Element."""
    # Extract all historical dates
    date_pairs = list()
    seen = set()
    for item in docsum.findall("Item[@Name='History']/Item[@Type='Date']"):
        name = item.get('Name')
        try:
            date_ = parse_date_text(item.text)
        except Exception as e:
            msg = 'article {}; name: {}; date: {}, threw: {}'.format(article['pubmed_id'], name, item.text, e)
            logging.warning(msg)
            continue
        
        date_pair = name, date_
        if date_pair in seen:
            continue
        seen.add(date_pair)
        date_pairs.append(date_pair)
    date_pairs.sort(key=lambda x: x[0])
    history = dict()
    for name, group in itertools.groupby(date_pairs, key=lambda x: x[0]):
        for i, (name, date_) in enumerate(group):
            history['{}_{}'.format(name, i)] = date_
    return history

# %%
path = os.path.join('download', 'esummary_journal-articles_1960-2015.xml.bz2')
articles = list()
n_articles = 0

parser = iterparse(path)
root = next(parser)
for elem in parser:
    if elem.tag != 'DocSum':
        continue
    
    n_articles += 1
    article = dict()
    article['pubmed_id'] = int(elem.findtext('Id'))
    article['journal_nlm_id'] = elem.findtext("Item[@Name='NlmUniqueID']")
    article.update(parse_esummary_history(elem))
    articles.append(article)
    
    # Reset element to free memory 
    root.clear()

n_articles, len(articles)
# Out:
# WARNING:root:article 11602027; name: received; date: -2152/01/-37 -10:-40, threw: year is out of range
# WARNING:root:article 11602028; name: received; date: -2152/01/74 -10:-40, threw: year is out of range
# WARNING:root:article 11602029; name: received; date: -2152/01/79 -10:-40, threw: year is out of range
# WARNING:root:article 11602030; name: received; date: -2152/01/89 -10:-40, threw: year is out of range
# WARNING:root:article 11602031; name: received; date: -2152/01/86 -10:-40, threw: year is out of range
# WARNING:root:article 11602032; name: received; date: -2152/01/-63 -10:-40, threw: year is out of range
# WARNING:root:article 11602033; name: received; date: -2152/01/-115 -10:-40, threw: year is out of range
# WARNING:root:article 11602034; name: received; date: -2152/01/-115 -10:-40, threw: year is out of range
# WARNING:root:article 11602035; name: received; date: -2152/01/102 -10:-40, threw: year is out of range
# WARNING:root:article 11602036; name: received; date: -2152/01/57 -10:-40, threw: year is out of range
# WARNING:root:article 11602037; name: received; date: -2152/01/-66 -10:-40, threw: year is out of range
# WARNING:root:article 11806858; name: received; date: -2152/01/-28 -10:-40, threw: year is out of range
# WARNING:root:article 11806859; name: received; date: -2152/01/-93 -10:-40, threw: year is out of range
# WARNING:root:article 11806860; name: received; date: -2152/01/-62 -10:-40, threw: year is out of range
# WARNING:root:article 11806861; name: received; date: -2151/01/-84 -10:-40, threw: year is out of range
# WARNING:root:article 11806862; name: received; date: -2152/01/74 -10:-40, threw: year is out of range
# WARNING:root:article 11806863; name: received; date: -2151/01/-102 -10:-40, threw: year is out of range
# WARNING:root:article 11806864; name: received; date: -2152/01/-42 -10:-40, threw: year is out of range
# WARNING:root:article 11806865; name: received; date: -2152/01/-28 -10:-40, threw: year is out of range
# WARNING:root:article 11806866; name: received; date: -2151/01/-70 -10:-40, threw: year is out of range
# WARNING:root:article 11806867; name: received; date: -2152/01/15 -10:-40, threw: year is out of range
# WARNING:root:article 11806868; name: received; date: -2152/01/99 -10:-40, threw: year is out of range
# WARNING:root:article 11851981; name: received; date: -2151/01/13 -10:-40, threw: year is out of range
# WARNING:root:article 11851982; name: received; date: -2151/01/-31 -10:-40, threw: year is out of range
# WARNING:root:article 11851983; name: received; date: -2151/01/-17 -10:-40, threw: year is out of range
# WARNING:root:article 11851984; name: received; date: -2151/01/-44 -10:-40, threw: year is out of range
# WARNING:root:article 11851985; name: received; date: -2151/01/-30 -10:-40, threw: year is out of range
# WARNING:root:article 11851986; name: received; date: -2151/01/-79 -10:-40, threw: year is out of range
# WARNING:root:article 11851987; name: received; date: -2152/01/00 -10:-40, threw: year is out of range
# WARNING:root:article 11851988; name: received; date: -2151/01/23 -10:-40, threw: year is out of range
# WARNING:root:article 16834792; name: revised; date: 0001/01/-26 00:00, threw: day is out of range for month
# WARNING:root:article 16834792; name: revised; date: 0001/01/-26 00:00, threw: day is out of range for month
# WARNING:root:article 19699551; name: accepted; date: -3156/01/-35 -4:-16, threw: year is out of range
# WARNING:root:article 23202684; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23202820; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23203039; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23222684; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23222686; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23235326; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23263666; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23303336; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23337201; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23340650; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23389305; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23389402; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23396192; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23434673; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23531490; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23549263; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23644828; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23685936; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23698168; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23727953; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23727954; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23748170; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23759989; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23812084; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23820534; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23820535; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23846726; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23857061; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23857224; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23884133; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23924959; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23945537; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23945538; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23945539; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23945642; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23945643; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23955321; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 23965964; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 24008376; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 24013489; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 24025558; name: revised; date: 0000/01/-31 00:00, threw: year is out of range
# WARNING:root:article 
missing_pct
# Out:
# medline_0         0.000000e+00
# pubmed_0          0.000000e+00
# entrez_0          9.399402e-07
# date_online       7.951436e-01
# aheadofprint_0    8.204849e-01
# received_0        8.393478e-01
# accepted_0        8.443315e-01
# revised_0         9.211524e-01
# epublish_0        9.706509e-01
# pmc-release_0     9.968478e-01
# ecollection_0     9.996401e-01
# ppublish_0        9.997162e-01
# version_0         9.999842e-01
# dtype: float64

# %%
article_df.tail()
# Out:
#           pubmed_id journal_nlm_id   medline_0    pubmed_0    entrez_0  \
# 22341843   26771983      101138582  2016-01-16  2016-01-16  2016-01-16
# 22341844   26771984      101138582  2016-01-16  2016-01-16  2016-01-16
# 22341845   26771985      101138582  2016-01-16  2016-01-16  2016-01-16
# 22341846   26771986      101138582  2016-01-16  2016-01-16  2016-01-16
# 22341847   26771990        7506858  2016-01-16  2016-01-16  2016-01-16
#
#          date_online aheadofprint_0 received_0 accepted_0 revised_0  \
# 22341843         NaN            NaN        NaN        NaN       NaN
# 22341844         NaN            NaN        NaN        NaN       NaN
# 22341845         NaN            NaN        NaN        NaN       NaN
# 22341846         NaN            NaN        NaN        NaN       NaN
# 22341847         NaN            NaN        NaN        NaN       NaN
#
#          epublish_0 pmc-release_0 ecollection_0 ppublish_0 version_0
# 22341843        NaN           NaN           NaN        NaN       NaN
# 22341844        NaN           NaN           NaN        NaN       NaN
# 22341845        NaN           NaN           NaN        NaN       NaN
# 22341846        NaN           NaN           NaN        NaN       NaN
# 22341847        NaN           NaN           NaN        NaN       NaN

# %%
# Save article_df
path = os.path.join('data', 'history-dates.tsv.bz2')
with bz2.open(path, 'wt') as write_file:
    article_df.to_csv(write_file, index=False, sep='\t')

# %% [markdown]
# # Process PubMed journal catalog
#
# Download and process PubMed/NLM [journal catalog](http://www.ncbi.nlm.nih.gov/books/NBK3827/table/pubmedhelp.T.journal_lists/).

# %%
# Download PubMed Journals
url = 'ftp://ftp.ncbi.nih.gov/pubmed/J_Medline.txt'
! wget --no-verbose --directory-prefix download --timestamping {url}

# %%
# Read PubMed journals
path = os.path.join('download', 'J_Medline.txt')
with open(path) as read_file:
    text = read_file.read()

# %%
# Create a dataframe of PubMed journals
rows = list()
pattern = re.compile('^-+$', re.MULTILINE)
for stanza in re.split(pattern, text):
    stanza = stanza.strip()
    if not stanza:
        continue
    row = dict()
    for line in stanza.split('\n'):
        key, value = line.split(': ', 1)
        row[key] = value or None
    rows.append(row)

journal_df = pandas.DataFrame(rows)
journal_df = journal_df.sort_values(by='NlmId')

# %%
# Order columns by percent missing
missing_pct = journal_df.isnull().mean().sort_values()
journal_df = journal_df[missing_pct.index]
missing_pct

# %%
# Save journal dataframe as a TSV
path = 'data/pubmed-journals.tsv'
journal_df.to_csv(path, sep='\t', index=False)
